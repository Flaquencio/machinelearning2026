# %% [markdown]
# # ITQ
#
# <img src= "img/ITQLogoING.jpeg" width="150"/>
#
# # PAO 2025-2026
# **Nombre:** *Israel Pabon* <br>
# **Fecha:** *07/01/2026*

# %% [markdown]
# # Introducción a Python
# Python es un lenguaje de programación de alto nivel <br>
# Tambien python me permite desarrollar aplicaciones de escritorio y web <br>

# %%
# Aquí va un comentario se usa el numeral para comentarios 
#system.out.print("Hola mundo")
print("Hola mundo")
# Out:
# Hola mundo

# %% [markdown]
# https://github.com/Flaquencio/machinelearning2026/blob/main/Introduccion.ipynb
