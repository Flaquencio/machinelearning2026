# %% [markdown]
# # ITQ
#
# <img src= "img/LogoITQ.png" width="50"/>
#
# # PAO 2025-2026
#
# **Nombre:** *Israel Pabon*
#
# **Fecha:** *30/03/2026*

# %% [markdown]
# <img src= "img/ITQLogoING.jpeg" width="150"/>
#
# # Variantes Cualitativas
#
# ![logo](img/PyLogoING.jpeg)
#
# **Israel Pabon**

# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Grado' 'Secundaria' 'Master' 'Bachillerato' 'Bachillerato' 'Doctorado'
#  'Bachillerato' 'Master' 'Secundaria' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Master' 'Grado' 'Master' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Master' 'Grado' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Grado' 'Doctorado' 'Grado' 'Secundaria' 'Bachillerato'
#  'Grado' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Master' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Doctorado'
#  'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Doctorado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Master' 'Secundaria'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado'
#  'Secundaria' 'Doctorado' 'Bachillerato' 'Bachillerato' 'Master' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Doctorado' 'Master'
#  'Secundaria' 'Doctorado' 'Bachillerato' 'Bachillerato' 'Doctorado'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Master' 'Master' 'Bachillerato' 'Grado' 'Grado'
#  'Doctorado' 'Grado' 'Grado' 'Secundaria' 'Secundaria' 'Secundaria'
#  'Master' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Doctorado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Master' 'Bachillerato'
#  'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Master' 'Bachillerato' 'Master' 'Grado' 'Secundaria' 'Bachillerato'
#  'Grado' 'Grado' 'Master' 'Master' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Master' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria' 'Grado'
#  'Bachillerato' 'Doctorado' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Master'
#  'Doctorado' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Secundaria'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Grado' 'Master' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Grado' 'Master' 'Grado' 'Bachillerato' 'Secundaria' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Grado' 'Secundaria' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria' 'Grado'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Master' 'Secundaria' 'Bachillerato' 'Grado'
#  'Grado' 'Master' 'Grado' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Master' 'Secundaria' 'Grado' 'Doctorado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Doctorado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Master' 'Master'
#  'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Master' 'Grado' 'Master' 'Grado' 'Bachillerato' 'Grado'
#  'Master' 'Master' 'Master' 'Grado' 'Grado' 'Bachillerato' 'Master'
#  'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Secundaria' 'Secundaria' 'Grado' 'Bachillerato'
#  'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Doctorado' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Grado' 'Master' 'Grado' 'Grado' 'Master'
#  'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Master' 'Grado'
#  'Master' 'Bachillerato' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Doctorado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Grado' 'Doctorado' 'Grado' 'Secundaria' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Master' 'Grado' 'Grado' 'Grado' 'Grado'
#  'Grado' 'Master' 'Master' 'Secundaria' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato' 'Grado'
#  'Secundaria' 'Doctorado' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Master' 'Master' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Master' 'Grado' 'Grado'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria' 'Master'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Master' 'Grado' 'Secundaria' 'Master' 'Grado' 'Master'
#  'Secundaria' 'Doctorado' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Master' 'Doctorado' 'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Grado'
#  'Master' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Doctorado' 'Bachillerato' 'Master' 'Grado' 'Secundaria' 'Grado'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Master' 'Secundaria' 'Master']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()

# %%
# Tarea implementar con pandas esta información 
import pandas as pd
import numpy as np

nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

df = pd.DataFrame(nivel_estudios, columns=['Nivel de estudios'])
print(df.head())
# Out:
#   Nivel de estudios
# 0      Bachillerato
# 1            Master
# 2      Bachillerato
# 3             Grado
# 4            Master

# %%
frecuencias = df['Nivel de estudios'].value_counts()
print(frecuencias)
# Out:
# Nivel de estudios
# Bachillerato    172
# Grado           145
# Secundaria      110
# Master           52
# Doctorado        21
# Name: count, dtype: int64

# %%
frecuencias.plot(kind='bar', xlabel='Nivel de estudios', ylabel='Frecuencia absoluta', title='Diagrama de barras')
plt.show()

# %%
frecuencias.plot(kind='pie', autopct='%1.2f%%', title='Diagrama de sectores')
plt.show()
